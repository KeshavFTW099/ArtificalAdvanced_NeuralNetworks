# %% [markdown]
# <a href="https://colab.research.google.com/github/KeshavFTW099/ArtificalAdvanced_NeuralNetworks/blob/main/ColourImages_%26CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

v = np.array([
    [1, 3, 2, 2],
    [0, 1, 3, 2]
])

plt.imshow(v, cmap='gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a random RGB image (4 × 4 × 3)
img = np.random.randint(0, 256, size=(4, 4, 3), dtype=np.uint8)

print(img)
# Out:
# [[[211 159  86]
#   [ 24  16 172]
#   [124 171 169]
#   [119 136  99]]
#
#  [[162 101 207]
#   [222 131 197]
#   [193 216 174]
#   [123 183 119]]
#
#  [[239  64   6]
#   [195 235 209]
#   [  1 128 158]
#   [201 146 237]]
#
#  [[ 61 109  16]
#   [  9 246 188]
#   [ 97 177  25]
#   [ 90 217  64]]]

# %%
# Original RGB Image
plt.subplot(221)
plt.imshow(img)
plt.title("All Channels Combined")

# Red Channel
plt.subplot(222)
plt.imshow(img[:, :, 0], cmap='Reds')
plt.title("Red Channel")

# Green Channel
plt.subplot(223)
plt.imshow(img[:, :, 1], cmap='Greens')
plt.title("Green Channel")

# Blue Channel
plt.subplot(224)
plt.imshow(img[:, :, 2], cmap='Blues')
plt.title("Blue Channel")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Conv2D
from scipy import misc

# Create a random RGB image
img = np.random.randint(0, 256, size=(4, 4, 3), dtype=np.uint8)

print("Image Array:")
print(img)
imgshow = plt.imshow(img)
plt.show()
# Out:
# Image Array:
# [[[153 136 171]
#   [189 214 192]
#   [ 73 221 214]
#   [152 208  30]]
#
#  [[150  65  52]
#   [119  56 118]
#   [ 92 226 208]
#   [120 197 221]]
#
#  [[ 81  76   7]
#   [222  99 168]
#   [251 126  79]
#   [ 54   3 111]]
#
#  [[117 183 118]
#   [  6 133 156]
#   [184  82  25]
#   [235 249  44]]]

# %%
print("Image Shape :", img.shape)
# Out:
# Image Shape : (4, 4, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D

# Create the Sequential Model
model = Sequential()

# Add Convolution Layer
model.add(
    Conv2D(
        1,
        kernel_size=(11,11),
        kernel_initializer='ones',
        input_shape=(512, 512, 1)
    )
)

model.compile(
    optimizer='adam',
    loss='mean_squared_error'
)

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 502, 502, 1)    │           122 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122 (488.00 B)
#  Trainable params: 122 (488.00 B)
#  Non-trainable params: 0 (0.00 B)
